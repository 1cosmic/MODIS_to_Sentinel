# %%
from utils import *
from prepare_ds import *
from train_ml import *
from create_map import *
from validation import *
from visualisation import *
from tqdm import tqdm
import matplotlib.pyplot as plt
from osgeo.gdal import GDT_UInt32

init()
# Out:
# Running cells with 'Geya (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Geya ipykernel --update-deps --force-reinstall'
